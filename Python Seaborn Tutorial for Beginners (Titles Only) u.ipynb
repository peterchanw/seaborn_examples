# %% [markdown]
# # Python Seaborn Tutorial for Beginners

# %% [markdown]
# ## What is Seaborn?
#
# - Python Data Visualization Library - based on MatPlotLib (see previous tutorials)
# - Used for plotting statistical graphs, identifying trends, relationships & outliers
# - In my opinion, Seaborn is easier & faster to use (less code) Vs MatPlotLib

# %%
# Visual representation of Seaborn

import os
from IPython.display import Image
PATH = "F:\\Github\\Python tutorials\\Introduction to Seaborn\\"
Image(filename = "Seaborn.png", width=900, height=900)

# %% [markdown]
# ## Tutorial Overview
#
# - What is Seaborn and how/why it's used
#
#
# - Trend Plots:
#     - Line Plots
#
#
# - Summary Plots:
#     - Bar Plots
#
#
# - Distribution of Data:
#     - Histogram
#     - Box Plots
#
#
# - Relationship Plots
#     - Scatter Plots
#     - lmplot (combo of regplot() and FacetGrid)
#
#
# - Holistic views / Combo:
#     - Sub Plots
#     - Pair Plots
#     - Join Plots
#
#
# - Correlation / Relationships:
#     - Heat Maps

# %% [markdown]
# ## Tutorial Overview by video
#
#
# ### Video 1:
# 1. What is seaborn and how/why it's used
# 2. Line Plots
# 3. Bar Plots
# 4. Histogram
#
# ### Video 2:
# 5. Box Plots
# 6. Scatter Plots
# 7. lmplot (combo of regplot() and FacetGrid)
#
# ### Video 3:
# 8. Sub Plots
# 9. Pair Plots
# 10. Join Plots
# 11. Heat Maps

# %% [markdown]
# ## Importing / Installing packages

# %%
# Packages / libraries
import os #provides functions for interacting with the operating system
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# To install seaborn type "pip install seaborn" to the anaconda terminal

# import sys
# !conda list Check the packages installed

# %% [markdown]
# ## 1. Loading the Raw Data

# %%
# Loading the data
raw_data = pd.read_csv('Marketing Raw Data.csv')

# runs all the data
raw_data
print(raw_data.shape)

#runs the first 5 rows
raw_data.head()
# Out:
# (182, 11)
#          Date  Week  Week_ID  Month  Month_ID  Year   Day_Name  Visitors  \
# 0  09/11/2020    46       34     11        11  2020     Monday       707
# 1  10/11/2020    46       34     11        11  2020    Tuesday      1455
# 2  11/11/2020    46       34     11        11  2020  Wednesday      1520
# 3  12/11/2020    46       34     11        11  2020   Thursday      1726
# 4  13/11/2020    46       34     11        11  2020     Friday      2134
#
#    Revenue  Marketing Spend           Promo
# 0      465          651.375        No Promo
# 1    10386         1298.250   Promotion Red
# 2    12475         1559.375  Promotion Blue
# 3    11712         1801.750        No Promo
# 4    10000         2614.500        No Promo

# %% [markdown]
# ## 2. Line Graph

# %%
# Example 1 - Simple 1 line graph
# Assuming we want to investigate the Revenue by Date

ax = sns.lineplot(x='Week_ID', y='Revenue', data=raw_data)

# Notes: error bands show the confidence interval

# %%
# Example 2 - Adding Categories
ax = sns.lineplot(x='Week_ID', y='Revenue', hue='Promo', data = raw_data, )
# By Promo

# %%
# Example 3 - By Promo with style
ax = sns.lineplot(x='Week_ID', y='Revenue', hue='Promo', data = raw_data, style='Promo' )

# %%
# Example 4 - By Promo with style & Increase the size & Remove error bars

# increase the size

sns.set(rc={'figure.figsize': (12,10)})
ax = sns.lineplot(x='Week_ID', y='Revenue', hue='Promo', data = raw_data, style='Promo', ci=False )

# %%
# Example 5 - By Promo with style & Increase the size & Remove error bars & adding markers & by month

sns.set(rc={'figure.figsize': (12,10)})
ax = sns.lineplot(x='Month_ID', y='Revenue', hue='Promo', data = raw_data, style='Promo', ci=False, markers=True )

# %%
# Example 6 - By Day_Name with style & Increase the size & Remove error bars & adding markers & by month

sns.set(rc={'figure.figsize': (12,10)})
ax = sns.lineplot(x='Month_ID', y='Revenue', hue='Day_Name', data = raw_data, style='Promo', ci=False, markers=True )

# %%
# Example 7 - By Year with style & Increase the size & Remove error bars & adding markers & by month

sns.set(rc={'figure.figsize': (12,10)})
ax = sns.lineplot(x='Year', y='Revenue', hue='Day_Name', data = raw_data, style='Promo', ci=False, markers=True )

# %% [markdown]
# ### LinePlot Documentation
# https://seaborn.pydata.org/generated/seaborn.lineplot.html

# %% [markdown]
# ## 3. Bar Plots

# %%
# Example 1 - Total Revenue by Month

sns.set(rc={'figure.figsize': (12,10)})
ax = sns.barplot(x='Month', y='Revenue', data=raw_data)

# Notes: 
# 1 - the lines signify the confidence interval
# 2 - Takes mean by default

# create a df with the mean values
raw_data[['Revenue', 'Month']].groupby('Month').agg({'Revenue':'mean'})
# Out:
#             Revenue
# Month
# 1       9588.516129
# 2      10683.892857
# 3      10555.354839
# 4      10806.500000
# 5       7636.000000
# 11     11255.454545
# 12     11667.806452

# %%
# Example 2 - Total Revenue by Month - Remove the Confidence Interval

sns.set(rc={'figure.figsize': (12,10)})
ax = sns.barplot(x='Month', y='Revenue', data=raw_data, ci=False)

# %%
# Example 3 - Total Revenue by Month - Remove the Confidence Interval - By Promo

sns.set(rc={'figure.figsize': (12,10)})
ax = sns.barplot(x='Month', y='Revenue', hue='Promo', data=raw_data, ci=False)

# %%
# Example 4 - Total Revenue by Month - Remove the Confidence Interval - By Promo - Changing direction

sns.set(rc={'figure.figsize': (12,10)})
ax = sns.barplot(x='Revenue', y='Month', hue='Promo', data=raw_data, ci=False, orient='h')

# %%
# Example 5 - Total Revenue by Month - Remove the Confidence Interval - By Promo - Changing direction - Changing Colour

sns.set(rc={'figure.figsize': (12,10)})
ax = sns.barplot(x='Revenue', y='Month', hue='Promo', data=raw_data, ci=False, orient='h', color='#FF33F2')

# Cool Way to pick colours
# https://htmlcolorcodes.com/color-picker/

# %% [markdown]
# ## 4. Histograms

# %%
# Example 1 - Investigating the distribution of Revenue

x = raw_data['Revenue'].values
sns.set(rc={'figure.figsize': (12,10)})
sns.distplot(x, color='blue')

# As you can see, it's a bit imbalance. Right skewd distribution as the mean is to the right

# %%
# Example 2 - Investigating the distribution of Revenue, adding the mean

x = raw_data['Revenue'].values
sns.set(rc={'figure.figsize': (12,10)})
sns.distplot(x, color='blue')

# Calculating the mean
mean = raw_data['Revenue'].mean()
print(mean)

#ploting the mean
plt.axvline(mean, 0,1, color = 'red')
# Out:
# 10581.593406593407

# %%
# Example 3 - Investigating the distribution of Visitors, adding the mean

x = raw_data['Visitors'].values
sns.set(rc={'figure.figsize': (12,10)})
sns.distplot(x, color='green')

# Calculating the mean
mean = raw_data['Visitors'].mean()
print(mean)

#ploting the mean - (0,1) plot along y-axis
plt.axvline(mean, 0,1, color = 'red')
# Out:
# 1666.7307692307693

# %% [markdown]
# ## 5. Box Plots

# %%
# Example 1 - Investigating the distribution of Revenue

x = raw_data['Revenue'].values
sns.set(rc={'figure.figsize': (12,10)})
sns.boxplot(x, color='#FF33F2')
median = raw_data['Revenue'].median()
print(median)

# Notes:
# The line signifies the median
# The box in the middle show the beginning of Q1 (25th percentile) and the end of the Q3 (75th percentile)
# The whiskers (left - right) show the minimum quartile and maximum quartile
# The dots on the right are "outliers"
# Out:
# 9452.0

# %%
# More Details

PATH = "F:\\Github\\Python tutorials\\Introduction to Seaborn\\"
Image(filename = PATH + "Seaborn boxplot.png", width=900, height=900)

# More details here: https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51
# Credits: Michael Galarnyk
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-6a97cf31754e> in <module>
#       2
#       3 PATH = "F:\\Github\\Python tutorials\\Introduction to Seaborn\\"
# ----> 4 Image(filename = PATH + "Seaborn boxplot.png", width=900, height=900)
#       5
#       6 # More details here: https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1195         self.unconfined = unconfined
#    1196         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1197                 metadata=metadata)
#    1198
#    1199         if self.width is None and self.metadata.get('width', {}):
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, metadata)
#     618             self.metadata = {}
#     619
# --> 620         self.reload()
#     621         self._check_data()
#     622
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\display.py in reload(self)
#    1226         """Reload the raw data from file or URL."""
#    1227         if self.embed:
# -> 1228             super(Image,self).reload()
#    1229             if self.retina:
#    1230                 self._retina_shape()
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\display.py in reload(self)
#     643         """Reload the raw data from file or URL."""
#     644         if self.filename is not None:
# --> 645             with open(self.filename, self._read_flags) as f:
#     646                 self.data = f.read()
#     647         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'F:\\Github\\Python tutorials\\Introduction to Seaborn\\Seaborn boxplot.png'

# %%
# Example 2 - Investigating the distribution of Revenue by Day
print(raw_data.columns)
sns.set(rc={'figure.figsize': (12,10)})
sns.boxplot(x='Day_Name',y='Revenue', data=raw_data)
# Out:
# Index(['Date', 'Week', 'Week_ID', 'Month', 'Month_ID', 'Year', 'Day_Name',
#        'Visitors', 'Revenue', 'Marketing Spend', 'Promo'],
#       dtype='object')

# %%
# Example 3 - Investigating the distribution of Revenue by Day - Horizontal - change color

sns.set(rc={'figure.figsize': (12,10)})
sns.boxplot(x='Revenue',y='Day_Name', data=raw_data, color='green')

# Cool Way to pick colours
# https://htmlcolorcodes.com/color-picker/

# %%
# Example 4 - Investigating the distribution of Revenue by Day - changing color - adding hue

sns.set(rc={'figure.figsize': (12,10)})
sns.boxplot(x='Day_Name',y='Revenue', data=raw_data, color='#FF33F2', hue='Promo')

# Cool Way to pick colours
# https://htmlcolorcodes.com/color-picker/

# %%
# Example 5 - Investigating the distribution of Revenue by Day - by color - by data points

sns.set(rc={'figure.figsize': (12,10)})
sns.boxplot(x='Day_Name',y='Revenue', data=raw_data, color='#eeff33')
sns.swarmplot(x='Day_Name',y='Revenue', data=raw_data, color='red')

# Cool Way to pick colours
# https://htmlcolorcodes.com/color-picker/

# %% [markdown]
# ### More on Boxplots here:
# https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn.boxplot

# %% [markdown]
# ## 6. ScatterPlots

# %%
# df columns
raw_data.columns
# Out:
# Index(['Date', 'Week', 'Week_ID', 'Month', 'Month_ID', 'Year', 'Day_Name',
#        'Visitors', 'Revenue', 'Marketing Spend', 'Promo'],
#       dtype='object')

# %%
# Example 1 - Relationship between Marketing Spend and Revenue

sns.set(rc={'figure.figsize': (12,10)})
sns.scatterplot(x='Marketing Spend',y='Revenue', data=raw_data)

# %%
# Example 2 - Relationship between Marketing Spend and Revenue - changing color, hue & Style

sns.set(rc={'figure.figsize': (12,10)})
sns.scatterplot(x='Marketing Spend',y='Revenue', data=raw_data, hue='Promo', style='Month')

# %%
# Example 3 - Relationship between Marketing Spend and Visitors - changing color & hue - adding size

sns.set(rc={'figure.figsize': (12,10)})
sns.scatterplot(x='Marketing Spend',y='Visitors', data=raw_data, hue='Promo', style='Month', size='Revenue',sizes=(20,200))

# %%
# Example 4 - Relationship between Marketing Spend and Revenue - changing color & hue - adding size - by day

sns.set(rc={'figure.figsize': (12,10)})
sns.scatterplot(x='Marketing Spend',y='Revenue', data=raw_data, hue='Day_Name', style='Promo', size='Revenue', sizes=(20,200))

# %% [markdown]
# ## 7. lmPlots

# %%
# Example 1 - Relationship between Marketing Spend and Revenue

sns.lmplot(x='Marketing Spend',y='Revenue', data=raw_data, height=10)

# Notes:
# What is Linear Regression: It is a predictive statistical method for modelling the relationship between x (independent variable) & y (dependent V).
# How it works (cost function MSE): https://towardsdatascience.com/machine-learning-fundamentals-via-linear-regression-41a5d11f5220

# %%
# Example 2 - Relationship between Marketing Spend and Revenue - changing color, hue & Style

sns.lmplot(x='Marketing Spend',y='Revenue', data=raw_data, ci=False, hue='Promo', markers=['o','x','*'], height=10)

# %%
# Example 3 - Relationship between Marketing Spend and Revenue - by column

sns.lmplot(x='Marketing Spend',y='Revenue', data=raw_data, col='Promo', ci=False, height=5, 
           line_kws={'color':'red'}, scatter_kws={'color':'green'})

# %%
# Example 4 - Relationship between Marketing Spend and Revenue - by column - by day - add Jitter too

sns.lmplot(x='Marketing Spend',y='Revenue', data=raw_data, col='Day_Name', ci=False, height=5, 
           line_kws={'color':'red'}, scatter_kws={'color':'green'}, col_wrap=3)

# %% [markdown]
# ## 8. SubPlots

# %%
# Set up the matplotlib figure
fig, axes = plt.subplots(2, 2, figsize=(12, 7))

a = raw_data['Revenue'].values
b = raw_data['Visitors'].values
c = raw_data['Marketing Spend'].values


# plot 1
sns.distplot(a, color = 'blue', ax=axes[0,0])

# plot 2
sns.distplot(b, color = 'green', ax=axes[0,1])

# plot 3
sns.distplot(c, color = 'red', ax=axes[1,0])

# plot 4
sns.boxplot(x="Revenue", y="Day_Name", data=raw_data, color = '#52F954', ax=axes[1,1])
sns.swarmplot(x="Revenue", y="Day_Name", data=raw_data, color="blue", ax=axes[1,1])

# %% [markdown]
# ## 9. Pairplots

# %%
# Example 1 - running on all dataframe - green color
g = sns.pairplot(raw_data, plot_kws={'color':'green'})

# %%
# Example 2 - running on specific columns - green color

g = sns.pairplot(raw_data[['Revenue','Visitors','Marketing Spend']], plot_kws={'color':'green'}, height=5)

# Cool Way to pick colours
# https://htmlcolorcodes.com/color-picker/

# %%
# Example 3 - running on specific columns - adding hue

g = sns.pairplot(raw_data[['Revenue','Visitors','Marketing Spend','Promo']], height=5, hue='Promo')

# %%
# Example 4 - running on specific columns - adding hue - adding kind = reg

g = sns.pairplot(raw_data[['Revenue','Visitors','Marketing Spend','Promo']], height=5, hue='Promo', kind='reg')

# %% [markdown]
# ### More on Pairplots:
# https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %% [markdown]
# ## 10. JointPlots
# #### Draw a plot of two variables with bivariate and univariate graphs.

# %%
# Example 1 - Revenue vs marketing Spend Relationship with 

ax = sns.jointplot('Marketing Spend','Revenue', data=raw_data, color='green', height=10, kind='reg')

# %% [markdown]
# ## 11. Heat Map

# %%
# First we need to create a "Dataset" to display on a Heatmap - we will use a correlation dataset
# .corr() is used to find the pairwise correlation of all columns in the dataframe. Any null values are automatically excluded
# The closer to 1 or -1 the better. As one variable increases, the other variable tends to also increase / decrease
# More Info here: https://statisticsbyjim.com/basics/correlations/

# %%
# Example 1 - Heatmap for PC
pc = raw_data[['Revenue','Marketing Spend','Visitors']].corr()
cols = ['Revenue CC','Visitors CC','Marketing Spend CC']
ax = sns.heatmap(pc, annot=True, square=True, 
                 annot_kws = {'size': 30},
                 xticklabels=cols,
                 yticklabels=cols)
# Fix for matplotlib v3.1.1 error using seaborn
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (3.0, 0.0)

# %%
# Example 2 - Heatmap for PC - changing cmap

pc = raw_data[['Revenue','Marketing Spend','Visitors']].corr()
cols = ['Revenue CC','Visitors CC','Marketing Spend CC']
ax = sns.heatmap(pc, annot=True, square=True, 
                 annot_kws = {'size': 30},
                 xticklabels=cols,
                 yticklabels=cols,
                 cmap = 'YlGnBu')
# Fix for matplotlib v3.1.1 error using seaborn
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)

# Examples:
# cmap="YlGnBu"
# cmap="Blues"
# cmap="BuPu"
# cmap="Greens"
# Out:
# (3.0, 0.0)

# %% [markdown]
# ### More details for Heatmaps here:
# https://seaborn.pydata.org/generated/seaborn.heatmap.html
